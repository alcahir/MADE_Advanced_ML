# %%
from typing import List, Dict, Tuple
from collections import defaultdict as dd
import os
import re

import pandas as pd
import numpy as np
from scipy import stats
from scipy.sparse import lil_matrix, coo_matrix
from sklearn.linear_model import LogisticRegression
from tqdm.notebook import tqdm

# %%
FOLDER = 'chgk'
NoReturn = None
EPS = 0.001

# %%
players = pd.read_pickle(os.path.join(FOLDER, "players.pkl"))
tournaments = pd.read_pickle(os.path.join(FOLDER, "tournaments.pkl"))

# %%
results = pd.read_pickle(os.path.join(FOLDER, "results.pkl"))

# %% [markdown]
# ### Tournaments dataset

# %%
tournaments = pd.DataFrame(tournaments.values())
tournaments['dateStart'] = pd.to_datetime(tournaments['dateStart'], format='%Y-%m-%d', utc=True)
tournaments['dateEnd'] = pd.to_datetime(tournaments['dateEnd'], format='%Y-%m-%d', utc=True)

# %%
tournaments = tournaments.set_index('id')
tournaments
# Out:
#                                                    name  \
# id
# 1                              Чемпионат Южного Кавказа
# 2                                           Летние зори
# 3                                      Турнир в Ижевске
# 4                    Чемпионат Украины. Переходной этап
# 5                                   Бостонское чаепитие
# ...                                                 ...
# 6481  Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эп...
# 6482                          Онлайн: 19:00 Зелёный шум
# 6483  Онлайн: 19:00 (а)Синхрон-lite. Лига старта. Эп...
# 6484      Онлайн: 22:00 Не числом, а умением - 2 (NEW!)
# 6485                 Онлайн: 19:00 Не числом, а умением
#
#                      dateStart                   dateEnd  \
# id
# 1    2003-07-24 20:00:00+00:00 2003-07-26 20:00:00+00:00
# 2    2003-08-08 20:00:00+00:00 2003-08-08 20:00:00+00:00
# 3    2003-11-21 21:00:00+00:00 2003-11-23 21:00:00+00:00
# 4    2003-10-10 20:00:00+00:00 2003-10-11 20:00:00+00:00
# 5    2003-10-09 20:00:00+00:00 2003-10-12 20:00:00+00:00
# ...                        ...                       ...
# 6481 2020-05-05 12:00:00+00:00 2020-05-05 15:00:00+00:00
# 6482 2020-05-07 16:00:00+00:00 2020-05-07 18:30:00+00:00
# 6483 2020-05-08 16:00:00+00:00 2020-05-08 18:30:00+00:00
# 6484 2020-05-04 19:00:00+00:00 2020-05-04 20:40:00+00:00
# 6485 2020-05-06 16:00:00+00:00 2020-05-06 17:45:00+00:00
#
#                               type       season  \
# id
# 1     {'id': 2, 'name': 'Обычный'}   /seasons/1
# 2     {'id': 2, 'name': 'Обычный'}   /seasons/1
# 3     {'id': 2, 'name': 'Обычный'}   /seasons/2
# 4     {'id': 2, 'name': 'Обычный'}   /seasons/2
# 5     {'id': 2, 'name': 'Обычный'}   /seasons/2
# ...                            ...          ...
# 6481  {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6482  {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6483  {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6484  {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6485  {'id': 2, 'name': 'Обычный'}  /seasons/53
#
#                                            orgcommittee synchData  \
# id
# 1                                                    []      None
# 2                                                    []      None
# 3                                                    []      None
# 4                                                    []      None
# 5                                                    []      None
# ...                                                 ...       ...
# 6481  [{'id': 7533, 'name': 'Денис', 'patronymic': '...      None
# 6482  [{'id': 7533, 'name': 'Денис', 'patronymic': '...      None
# 6483  [{'id': 7533, 'name': 'Денис', 'patronymic': '...      None
# 6484  [{'id': 7533, 'name': 'Денис', 'patronymic': '...      None
# 6485  [{'id': 7533, 'name': 'Денис', 'patronymic': '...      None
#
#                       questionQty
# id
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# 5                            None
# ...                           ...
# 6481  {'1': 12, '2': 12, '3': 12}
# 6482  {'1': 13, '2': 13, '3': 13}
# 6483  {'1': 12, '2': 12, '3': 12}
# 6484           {'1': 12, '2': 12}
# 6485           {'1': 12, '2': 12}
#
# [5528 rows x 8 columns]

# %% [markdown]
# I break down dataset into 2 parts: <br>
# * Train - 2019 year <br>
# * Test - 2020 year <br>

# %%
train_tournaments = tournaments[(tournaments['dateStart'] >= '2019-01-01') & (tournaments['dateStart'] < '2020-01-01')]
test_tournaments = tournaments[(tournaments['dateStart'] >= '2020-01-01') & (tournaments['dateStart'] < '2021-01-01')]

# %%
train_tournaments = train_tournaments[train_tournaments.index.isin(results.keys())]
test_tournaments = test_tournaments[test_tournaments.index.isin(results.keys())]

# %%
test_tournaments
# Out:
#                                                    name  \
# id
# 4628                                         Семь сорок
# 4957                                 Синхрон Биркиркары
# 5151                                             Яровой
# 5414                             Синхрон северных стран
# 5477                        Онлайн: Синхрон Урюбджирова
# ...                                                 ...
# 6481  Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эп...
# 6482                          Онлайн: 19:00 Зелёный шум
# 6483  Онлайн: 19:00 (а)Синхрон-lite. Лига старта. Эп...
# 6484      Онлайн: 22:00 Не числом, а умением - 2 (NEW!)
# 6485                 Онлайн: 19:00 Не числом, а умением
#
#                      dateStart                   dateEnd  \
# id
# 4628 2020-12-30 13:00:00+00:00 2020-12-30 13:00:00+00:00
# 4957 2020-02-20 21:00:00+00:00 2020-02-27 20:00:00+00:00
# 5151 2020-08-01 11:00:00+00:00 2020-08-05 11:00:00+00:00
# 5414 2020-01-03 16:00:00+00:00 2020-01-10 16:00:00+00:00
# 5477 2020-04-18 16:00:00+00:00 2020-04-30 16:00:00+00:00
# ...                        ...                       ...
# 6481 2020-05-05 12:00:00+00:00 2020-05-05 15:00:00+00:00
# 6482 2020-05-07 16:00:00+00:00 2020-05-07 18:30:00+00:00
# 6483 2020-05-08 16:00:00+00:00 2020-05-08 18:30:00+00:00
# 6484 2020-05-04 19:00:00+00:00 2020-05-04 20:40:00+00:00
# 6485 2020-05-06 16:00:00+00:00 2020-05-06 17:45:00+00:00
#
#                                type       season  \
# id
# 4628   {'id': 3, 'name': 'Синхрон'}         None
# 4957   {'id': 3, 'name': 'Синхрон'}  /seasons/53
# 5151   {'id': 3, 'name': 'Синхрон'}  /seasons/53
# 5414   {'id': 3, 'name': 'Синхрон'}  /seasons/53
# 5477  {'id': 8, 'name': 'Асинхрон'}  /seasons/53
# ...                             ...          ...
# 6481   {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6482   {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6483   {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6484   {'id': 2, 'name': 'Обычный'}  /seasons/53
# 6485   {'id': 2, 'name': 'Обычный'}  /seasons/53
#
#                                            orgcommittee  \
# id
# 4628  [{'id': 7533, 'name': 'Денис', 'patronymic': '...
# 4957  [{'id': 2421, 'name': 'Ася', 'patronymic': 'Се...
# 5151  [{'id': 22325, 'name': 'Михаил', 'patronymic':...
# 5414  [{'id': 28379, 'name': 'Константин', 'patronym...
# 5477  [{'id': 91324, 'name': 'Эрдни', 'patronymic': ...
# ...                                                 ...
# 6481  [{'id': 7533, 'name': 'Денис', 'patronymic': '...
# 6482  [{'id': 7533, 'name': 'Денис', 'patronymic': '...
# 6483  [{'id': 7533, 'name': 'Денис', 'patronymic': '...
# 6484  [{'id': 7533, 'name': 'Денис', 'patronymic': '...
# 6485  [{'id': 7533, 'name': 'Денис', 'patronymic': '...
#
#                                               synchData  \
# id
# 4628  {'dateRequestsAllowedTo': '2020-12-30T23:55:00...
# 4957  {'dateRequestsAllowedTo': '2020-02-27T18:00:00...
# 5151  {'dateRequestsAllowedTo': '2020-07-24T23:59:59...
# 5414  {'dateRequestsAllowedTo': '2020-01-10T23:59:00...
# 5477  {'dateRequestsAllowedTo': '2020-04-30T23:55:00...
# ...                                                 ...
# 6481                                               None
# 6482                                               None
# 6483                                               None
# 6484                                               None
# 6485                                               None
#
#                       questionQty
# id
# 4628  {'1': 12, '2': 12, '3': 12}
# 4957  {'1': 13, '2': 13, '3': 13}
# 5151  {'1': 12, '2': 12, '3': 12}
# 5414  {'1': 12, '2': 12, '3': 12}
# 5477  {'1': 12, '2': 12, '3': 12}
# ...                           ...
# 6481  {'1': 12, '2': 12, '3': 12}
# 6482  {'1': 13, '2': 13, '3': 13}
# 6483  {'1': 12, '2': 12, '3': 12}
# 6484           {'1': 12, '2': 12}
# 6485           {'1': 12, '2': 12}
#
# [416 rows x 8 columns]

# %% [markdown]
# ### Players dataset

# %%
players = pd.DataFrame(players.values())

# %%
players = players.set_index('id')

# %%
players
# Out:
#              name  patronymic    surname
# id
# 1         Алексей        None   Абабилов
# 10          Игорь                 Абалов
# 11        Наталья     Юрьевна  Абалымова
# 12          Артур  Евгеньевич    Абальян
# 13           Эрик  Евгеньевич    Абальян
# ...           ...         ...        ...
# 224700      Артём  Евгеньевич      Садов
# 224701     Даниил    Олегович   Трефилов
# 224702   Владимир  Араратович   Басенцян
# 224703     Руслан   Ринатович   Дауранов
# 224704  Александр  Викторович    Гапонов
#
# [204063 rows x 3 columns]

# %% [markdown]
# Отфильтруем турниры, таким образом, чтобы в "рабочие" турниры попали только те, команды которых имеют не побитую маску ответом на вопросы. А именно, если в маске встречается X, то просто пропускаем такой вопрос, а остальные приводим к целому числу. Если же так получилось, что в команде нет игроков вообще, либо маска полностью невалидная, то игнорируем такую команду как будто её исключили из турнира за странное поведение. Может случится так, что на всём турнире не нашлось команд, маски которых удовлетворяют условию выше, в таком случае такой турнир будет исключён из рассмотрения. <br>
# Откорректируем рейтинги команд простой последовательной нумерацией(без учёта ничьи) в турнирах, где были отсеяны некоторые команды.

# %%
def filter_valid_rating(tour_res, tour_indexes) -> NoReturn:
    invalids_num = 0
    
    for indx in tour_indexes:
        tour_capacity = len(tour_res[indx])
        valid_teams = []
        for team in tour_res[indx]:
            if team.get('mask'):
                updated_mask = list(map(int, [symbol for symbol in team['mask'] if symbol.isdigit()]))
                if updated_mask and team['teamMembers']:
                    team['mask'] = updated_mask 
                    valid_teams.append(team)
        
        if len(valid_teams) == 0:
            print(f'Tournament ({tournaments.loc[indx, "name"]}) consists of invalid teams...')
            invalids_num += 1
            del tour_res[indx]
            continue
        
        if len(valid_teams) != tour_capacity:
            print(f"Tournament ({tournaments.loc[indx, 'name']}) is invalid, but {len(valid_teams)} teams are valid")
            rating = 1
            for team in valid_teams:
                team['rating'] = rating
                rating += 1
            tour_res[indx] = valid_teams
    
    return tour_res

# %% [markdown]
# Если в данных есть некоррекные маски, то будем их выбрасывать и корректировать рейтинги команд в соответствии с исправлениями, но, к сожалению, непонятно как при этом учитывать рейтинги, где была ничья

# %%
results = filter_valid_rating(results, list(train_tournaments.index) + list(test_tournaments.index))
# Out:
# Tournament (ОВСЧ. 6 этап) is invalid, but 907 teams are valid
# Tournament (Синхрон-lite. Выпуск XXIII) is invalid, but 485 teams are valid
# Tournament (Поволжская лига) is invalid, but 5 teams are valid
# Tournament (Синхронный Кубок Ростова - общий зачёт) is invalid, but 34 teams are valid
# Tournament (Школьный чемпионат Украины) consists of invalid teams...
# Tournament (Город грехов) is invalid, but 120 teams are valid
# Tournament (Славянка без раздаток. Общий зачёт) is invalid, but 582 teams are valid
# Tournament (Гран-при Славянки. Общий зачёт) is invalid, but 561 teams are valid
# Tournament (Вторая лига чемпионата Харьковской области) consists of invalid teams...
# Tournament (Первая лига чемпионата Харьковской области) consists of invalid teams...
# Tournament (Высшая лига чемпионата Харьковской области) consists of invalid teams...
# Tournament (Молодёжный чемпионат Нижегородской области) is invalid, but 22 teams are valid
# Tournament (Октавы: Гала-турнир. Лига Наций: Прибалтика) consists of invalid teams...
# Tournament (Гран-при МГУ) consists of invalid teams...
# Tournament (Школьный Синхрон-lite. Выпуск 3.1) is invalid, but 353 teams are valid
# Tournament (Школьный Синхрон-lite. Выпуск 3.3) is invalid, but 359 teams are valid
# Tournament ((а)Синхрон-lite. Лига старта. Эпизод IX) is invalid, but 304 teams are valid
# Tournament (Школьный Синхрон-lite. Выпуск 3.4) is invalid, but 316 teams are valid
# Tournament (Школьный Синхрон-lite. Выпуск 3.5) is invalid, but 341 teams are valid
# Tournament (Синхрон-lite. Выпуск XXVII) is invalid, but 639 teams are valid
# Tournament ( Балтийский Берег. Общий зачёт) is invalid, but 1920 teams are valid
# Tournament (ОВСЧ. 4 этап) is invalid, but 946 teams are valid
# Tournament (Летний кубок Армении) consists of invalid teams...
# Tournament (Гран-при Славянки. Общий зачет) is invalid, but 356 teams are valid
# Tournament ((А) Гран-при Славянки. 4 этап) consists of invalid teams...
# Tournament (Černe ČGK) consists of invalid teams...
# Tournament (Школьная лига. I тур.) is invalid, but 698 teams are valid
# Tournament (Школьная лига. III тур.) is invalid, but 612 teams are valid
# Tournament (Кубок малых городов) is invalid, but 77 teams are valid
# Tournament (Из Минска с любовью. Этап 1.) is invalid, but 42 teams are valid
# Tournament (Осенний марафон) consists of invalid teams...
# Tournament (Серия Гран-при. Общий зачёт) is invalid, but 537 teams are valid
# Tournament (Чемпионат Москвы. Высшая лига) consists of invalid teams...
# Tournament (Асинхрон турнира "Год театра") is invalid, but 68 teams are valid
# Tournament (Школьный синхрон-lite. Сезон 3) is invalid, but 789 teams are valid
# Tournament (Школьная лига) is invalid, but 841 teams are valid
# Tournament (ОВСЧ) is invalid, but 2009 teams are valid
# Tournament (19:00 B-Quiz Online) consists of invalid teams...
# Tournament (Семь сорок) consists of invalid teams...
# Tournament (Яровой) consists of invalid teams...
# Tournament (Онлайн: Синхрон Урюбджирова) is invalid, but 99 teams are valid
# Tournament (Любовь, смерть и киберразумисты) consists of invalid teams...
# Tournament (Онлайн: Geek-ЧГК. Светлая сторона) consists of invalid teams...
# Tournament (Синхрон Мишеля Матвеева) consists of invalid teams...
# Tournament (Школьный Синхрон-lite. Выпуск 3.6) is invalid, but 291 teams are valid
# Tournament (Школьный Синхрон-lite. Выпуск 3.7) is invalid, but 106 teams are valid
# Tournament (Онлайн: (а)Синхрон-lite. Лига старта. Эпизод XV) consists of invalid teams...
# Tournament ((а)Синхрон-lite. Лига старта. Эпизод XVI) consists of invalid teams...
# Tournament ((а)Синхрон-lite. Лига старта. Эпизод XVII) consists of invalid teams...
# Tournament (Онлайн: Синхрон-lite. Выпуск XXXIV) is invalid, but 332 teams are valid
# Tournament (Онлайн: Синхрон-lite. Выпуск XXXV) consists of invalid teams...
# Tournament (Задача трёх тел-2) consists of invalid teams...
# Tournament (Синхрон десятилетия Белого шума) consists of invalid teams...
# Tournament (Балтийский Берег. 5 игра) consists of invalid teams...
# Tournament (Кубок городов) consists of invalid teams...
# Tournament (Кубок Чемпионов) consists of invalid teams...
# Tournament (Октавы: Гала-турнир) consists of invalid teams...
# Tournament (Восьмая октава) consists of invalid teams...
# Tournament (Лига Сибири. VI тур.) consists of invalid teams...
# Tournament (Гусарская лига. III сезон. IV этап) consists of invalid teams...
# Tournament (Серия Гран-при. 7 этап. Гран-при России) consists of invalid teams...
# Tournament (5 o'clock (зеркало)) consists of invalid teams...
# Tournament (Кубок регионов) consists of invalid teams...
# Tournament (Вопросы) consists of invalid teams...
# Tournament (Студенческий чемпионат Беларуси) consists of invalid teams...
# Tournament (Синхронный студенческий Кубок Беларуси) consists of invalid teams...
# Tournament (Открытый чемпионат БГУИР) consists of invalid teams...
# Tournament (Любовь, Асинхрон и Весна (18+)) consists of invalid teams...
# Tournament (Первенство Правого Полушария) consists of invalid teams...
# Tournament (Кубок Крамбамбули) consists of invalid teams...
# Tournament (Школьная лига. IV тур.) is invalid, but 639 teams are valid
# Tournament (Школьная лига. V тур.) is invalid, but 499 teams are valid
# Tournament (Синхрон с человеческим лицом VII) consists of invalid teams...
# Tournament (Уходящая натура) consists of invalid teams...
# Tournament (Донат) consists of invalid teams...
# Tournament (D.I.S.C.O.) consists of invalid teams...
# Tournament (Топ-1000) consists of invalid teams...
# Tournament (Синхрон Моносова) consists of invalid teams...
# Tournament (Кубок Квасира) consists of invalid teams...
# Tournament (Железный капут) consists of invalid teams...
# Tournament (Кубок Витебска) consists of invalid teams...
# Tournament (Славянка без раздаток. 3 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 3 этап) consists of invalid teams...
# Tournament (Славянка без раздаток. 4 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 4 этап) consists of invalid teams...
# Tournament (Славянка без раздаток. 5 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 5 этап) consists of invalid teams...
# Tournament (Славянка без раздаток. 6 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 6 этап) consists of invalid teams...
# Tournament (Славянка без раздаток. 7 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 7 этап) consists of invalid teams...
# Tournament (Франкфуртская школа) consists of invalid teams...
# Tournament (Франкфуртская школа: Познание и интерес) consists of invalid teams...
# Tournament (Франкфуртская школа: Разум и революция) consists of invalid teams...
# Tournament (Кубок княгини Ольги) consists of invalid teams...
# Tournament (Кубок Новополоцка) consists of invalid teams...
# Tournament (Франкфуртская школа: Эрос и цивилизация) consists of invalid teams...
# Tournament (Франкфуртская школа: Эрос и цивилизация) consists of invalid teams...
# Tournament (Кубок Ярослава Мудрого) consists of invalid teams...
# Tournament (Синхронный кубок Эмилии Плятер — первая часть) consists of invalid teams...
# Tournament (SYN.CHRO) consists of invalid teams...
# Tournament (Зеркало абстрактного турнира) consists of invalid teams...
# Tournament (Meditarranean Cup) consists of invalid teams...
# Tournament (Кубок Мальты) consists of invalid teams...
# Tournament (Чемпионат Великобритании) consists of invalid teams...
# Tournament (Кубок 50-й параллели) consists of invalid teams...
# Tournament (Девятый круг) consists of invalid teams...
# Tournament (Мемориал Виталия Маруды) consists of invalid teams...
# Tournament (Кубок содружества) consists of invalid teams...
# Tournament (Кубок молодёжи) consists of invalid teams...
# Tournament (Кубок княгини Ольги (среди школьников)) consists of invalid teams...
# Tournament (Топ-1000) consists of invalid teams...
# Tournament (Молодёжный кубок Европы. Этап 2) consists of invalid teams...
# Tournament (Антибинго) consists of invalid teams...
# Tournament (Кубок Союзного государства) consists of invalid teams...
# Tournament (Кубок Брестской области) consists of invalid teams...
# Tournament (Кубок кабачков. Цветение) consists of invalid teams...
# Tournament (Онлайн: Парный асинхронный турнир ChGK is...) is invalid, but 708 teams are valid
# Tournament (Открытый кубок Дальнего Востока) consists of invalid teams...
# Tournament (Открытый кубок Дальнего Востока среди школьных и студенческих команд) consists of invalid teams...
# Tournament (Синхрон простых вопросов. Весна) consists of invalid teams...
# Tournament (Серия Premier. Кубок светлых лошадок) consists of invalid teams...
# Tournament (Дилижанские Игры) consists of invalid teams...
# Tournament (Весна в ЛЭТИ) consists of invalid teams...
# Tournament (Триптих. Лето) consists of invalid teams...
# Tournament (Триптих. Осень) consists of invalid teams...
# Tournament (Синхрон Олимпийского Кубка Беларуси. День 2) consists of invalid teams...
# Tournament (Moon Pie) consists of invalid teams...
# Tournament (С чаем пойдёт (black)) consists of invalid teams...
# Tournament (Поволжская лига) consists of invalid teams...
# Tournament (Онлайн: Кубок Бесконечности. VII этап: Финал) consists of invalid teams...
# Tournament (Открытый чемпионат Польши) consists of invalid teams...
# Tournament (Шостая актава: Ліга нацый: Беларусь) consists of invalid teams...
# Tournament (Турнирум) consists of invalid teams...
# Tournament (Чемпионат Казахстана) consists of invalid teams...
# Tournament (Онлайн: Кубик Бесконечности. Первый бросок) consists of invalid teams...
# Tournament (Кубик Бесконечности: второй бросок) consists of invalid teams...
# Tournament (Кубик Бесконечности: третий бросок) consists of invalid teams...
# Tournament (Не числом, а умением) consists of invalid teams...
# Tournament (PostModern Talking) consists of invalid teams...
# Tournament (Гран-при Бауманки. 4 этап) consists of invalid teams...
# Tournament (Гран-при Бауманки. 5 этап) consists of invalid teams...
# Tournament (Гран-при Бауманки. 6 этап) consists of invalid teams...
# Tournament (Синхрон Первенства Сахалина) consists of invalid teams...
# Tournament (Лига вузов. Финал) consists of invalid teams...
# Tournament (Кубок мэра Иркутска) consists of invalid teams...
# Tournament (Кубок губернатора Иркутской области) consists of invalid teams...
# Tournament (Славянка без раздаток. 8 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 8 этап) consists of invalid teams...
# Tournament (Славянка без раздаток. 9 этап) consists of invalid teams...
# Tournament (Гран-при Славянки. 9 этап) consists of invalid teams...
# Tournament (ОВСЧ. 1 этап) consists of invalid teams...
# Tournament (ОВСЧ. 2 этап) consists of invalid teams...
# Tournament (ОВСЧ. 3 этап) consists of invalid teams...
# Tournament (ОВСЧ. 4 этап) consists of invalid teams...
# Tournament (ОВСЧ. 5 этап) consists of invalid teams...
# Tournament (Арктическое зеркало) consists of invalid teams...
# Tournament (Альпийский Эдельвейс) consists of invalid teams...
# Tournament (Зеркало Альпийского Эдельвейса) consists of invalid teams...
# Tournament (Интеллектуальная олимпиада ПФО среди студентов. Региональный этап) is invalid, but 92 teams are valid
# Tournament (Возраст согласия) consists of invalid teams...
# Tournament (Благородный Дон) consists of invalid teams...
# Tournament (Чемпионат Швеции) consists of invalid teams...
# Tournament (Сёмая актава. Ліга нацый: Беларусь) consists of invalid teams...
# Tournament (Онлайн: Лёгкий Смоленск Grand) consists of invalid teams...
# Tournament (Тыквенный пирог) consists of invalid teams...
# Tournament (Франкфуртская школа: Философия новой музыки) consists of invalid teams...
# Tournament (Українська ліга. Етап 4) consists of invalid teams...
# Tournament (Студенческий чемпионат России (перенесён, даты пока неточные)) consists of invalid teams...
# Tournament (Угрюмоватый Ёршик) consists of invalid teams...
# Tournament (Мартовский лев) consists of invalid teams...
# Tournament (Онлайн: Весенняя кинолига) consists of invalid teams...
# Tournament (Бужский гард-6) consists of invalid teams...
# Tournament (Кубок Джерри Мок) consists of invalid teams...
# Tournament (Интеллектуальная ворона) consists of invalid teams...
# Tournament (Зеркало Мартовского льва) consists of invalid teams...
# Tournament (Школьный чемпионат Беларуси) consists of invalid teams...
# Tournament (Школьнае люстэрка) consists of invalid teams...
# Tournament (Маленькае люстэрка) consists of invalid teams...
# Tournament ( Весна в ЛЭТИ: широкий прокат) consists of invalid teams...
# Tournament (Чемпионат МГУ. Высшая лига. Третий игровой день) consists of invalid teams...
# Tournament (Чемпионат МГУ. Открытая лига. Третий игровой день) consists of invalid teams...
# Tournament (Каменный цветок) consists of invalid teams...
# Tournament (Город грехов) consists of invalid teams...
# Tournament (Мемориал Владимира Гусарова) consists of invalid teams...
# Tournament (Geek-ЧГК. Тёмная сторона) consists of invalid teams...
# Tournament (Занавес неведения 2) consists of invalid teams...
# Tournament (Олимпиада Приволжского федерального округа. Финал) consists of invalid teams...
# Tournament (AU) consists of invalid teams...
# Tournament (ОКР) consists of invalid teams...
# Tournament (Синхронный кубок Эмилии Плятер — вторая часть) consists of invalid teams...
# Tournament (Онлайн: Чизкейк $1) consists of invalid teams...
# Tournament (Онлайн: Зелёный шум) consists of invalid teams...
# Tournament (Асинхрон по сериалу "След") consists of invalid teams...
# Tournament (Чемпионат Израиля) consists of invalid teams...
# Tournament (Ultima Tule) consists of invalid teams...
# Tournament (Новые реалии - I) consists of invalid teams...
# Tournament (Славянка-2020. День первый) consists of invalid teams...
# Tournament (Славянка-2020. День второй) consists of invalid teams...
# Tournament (Кубок малой родины-2020. День первый) consists of invalid teams...
# Tournament (Кубок малой родины-2020. День второй) consists of invalid teams...
# Tournament (Онлайн: Асинхрон Кубок соседней галактики. Дельта) consists of invalid teams...
# Tournament (Асинхрон по мемам) consists of invalid teams...
# Tournament (Онлайн: Донат $1) consists of invalid teams...
# Tournament (Онлайн: 14:00 Клуб Онлайн Вопросов. 2-я игра. 1-й эфир) consists of invalid teams...
# Tournament (Онлайн: 19:00 Клуб Онлайн Вопросов. 2-я игра. 2-й эфир) consists of invalid teams...
# Tournament (Онлайн: 14:00 Клуб Онлайн Вопросов. 3-я игра. 1-й эфир) consists of invalid teams...
# Tournament (Онлайн: 19:00 Клуб Онлайн Вопросов. 3-я игра. 2-й эфир) consists of invalid teams...
# Tournament (Онлайн: 14:00 Клуб Онлайн Вопросов. 4-я игра. 1-й эфир) consists of invalid teams...
# Tournament (Онлайн: 19:00 Клуб Онлайн Вопросов. 4-я игра. 2-й эфир) consists of invalid teams...
# Tournament (Онлайн: Тыквенный пирог $1) consists of invalid teams...
# Tournament (Онлайн: 15:00 Весенняя кинолига) consists of invalid teams...
# Tournament (Онлайн: 01:00 Delivery Cup) consists of invalid teams...
# Tournament (Онлайн: 20:00 Genium Challenge Online) consists of invalid teams...
# Tournament (Эйрамджан в Гуанахуато) consists of invalid teams...
# Tournament (Онлайн: Кубок кубков) consists of invalid teams...
# Tournament (Летняя кинолига) consists of invalid teams...
# Tournament (Онлайн: 15-30 Пегас и лирохвост) consists of invalid teams...
# Tournament (Онлайн: 19-30 Пегас и лирохвост) consists of invalid teams...
# Tournament (Онлайн: Большая игра. М-лига) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 23:00 Большая игра: Международная лига) consists of invalid teams...
# Tournament (Онлайн: 13:00 Большая игра: Международная лига) consists of invalid teams...
# Tournament (Онлайн: 19-30 Tet-a-tet+  для пар и троек.) consists of invalid teams...
# Tournament (Онлайн: 20-00 Tet-a-tet+ для пар и троек.) consists of invalid teams...
# Tournament (Онлайн: IPA $1) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 15:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 19:00 (а)Синхрон-lite. Лига старта. Эпизод XIV) consists of invalid teams...
# Tournament (Онлайн: 19:00 Синхрон-lite. Выпуск XXXIV) consists of invalid teams...
# Tournament (Онлайн: 15:00 Лёгкий Смоленск-5) consists of invalid teams...
# Tournament (Онлайн: 15:00 Синхрон Урюбджирова) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 13:00 Синхрон-lite. Выпуск XXXIV) consists of invalid teams...
# Tournament (Онлайн: 23:00 Большая игра: Международная лига. 2-я игра) consists of invalid teams...
# Tournament (Онлайн: 13:00 Большая игра: Международная лига. 2-я игра) consists of invalid teams...
# Tournament (Онлайн: 19:00 Синхрон Урюбджирова) consists of invalid teams...
# Tournament (Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эпизод XIV) consists of invalid teams...
# Tournament (Онлайн: 19:00 Синхрон-lite. Выпуск XXXIV) consists of invalid teams...
# Tournament (Онлайн: 15:00 Лёгкий Смоленск-5) consists of invalid teams...
# Tournament (Онлайн: 19:00 Синхрон Урюбджирова) consists of invalid teams...
# Tournament (Онлайн: 15:00 Синхрон-lite. Выпуск XXXIV) consists of invalid teams...
# Tournament (Онлайн: 16:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: Тематический асинхрон Stay Home) consists of invalid teams...
# Tournament (Онлайн: 21:15 Лёгкий Смоленск-5) consists of invalid teams...
# Tournament (Онлайн: 21:30 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 15:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 21:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 21:30 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 21:00 Синхрон Урюбджирова) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 18:00 Синхрон-lite. Выпуск XXXIV) consists of invalid teams...
# Tournament (Онлайн: 21:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эпизод XIV) consists of invalid teams...
# Tournament (Онлайн: Декамерон 18:00) consists of invalid teams...
# Tournament (Онлайн: асинхронный Декамерон) consists of invalid teams...
# Tournament (Онлайн: 21:00 Зелёный шум) consists of invalid teams...
# Tournament (Онлайн: 18:30 Зелёный шум) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 21:30 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 15:00 Синхрон-lite. Выпуск XXXIV) consists of invalid teams...
# Tournament (Онлайн: 21:00 Синхрон Урюбджирова) consists of invalid teams...
# Tournament (Онлайн: 21:00 Зелёный шум) consists of invalid teams...
# Tournament (Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эпизод XIV) consists of invalid teams...
# Tournament (Онлайн: 19:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 19:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 15:00 Не числом, а умением) consists of invalid teams...
# Tournament (Онлайн: 21:30 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: FatLazyRaccoon Cup) consists of invalid teams...
# Tournament (Онлайн: Tet-a-tet+  1$) consists of invalid teams...
# Tournament (Онлайн: Joystick Cup 2019 (видеоигры)) consists of invalid teams...
# Tournament (Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 22:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 21:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 18:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 12:30 Лёгкий Смоленск Grand) consists of invalid teams...
# Tournament (Онлайн: 19:00 Асинхронный «Декамерон» (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 19:00 Асинхронный «Декамерон» (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 21:00 Асинхронный «Декамерон» (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 22:00 Зелёный шум) consists of invalid teams...
# Tournament (Онлайн: 15:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 19:00 Зелёный шум) consists of invalid teams...
# Tournament (Онлайн: 19:00 (а)Синхрон-lite. Лига старта. Эпизод XV (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 22:00 Не числом, а умением - 2 (NEW!)) consists of invalid teams...
# Tournament (Онлайн: 19:00 Не числом, а умением) consists of invalid teams...

# %%
train_tournaments = train_tournaments[train_tournaments.index.isin(results.keys())]
test_tournaments = test_tournaments[test_tournaments.index.isin(results.keys())]

# %%
def get_tour_statistics(tour_res, tour_indexes):
    player_ans_correct = dd(int)
    tour_quest_quantity = dict()
    
    for tour_indx in tour_indexes:
        max_size = 0
        for team in tour_res[tour_indx]:
            quest_size = len(team['mask'])
            if max_size < quest_size:
                max_size = quest_size
                
            for member in team['teamMembers']:
                player_id = member['player']['id']
                player_correct_answers = sum(team['mask'])
                player_ans_correct[player_id] += player_correct_answers
                
        tour_quest_quantity[tour_indx] = max_size
            
    return player_ans_correct, tour_quest_quantity

# %%
train_player_ans_correct, train_tour_quest_quantity = get_tour_statistics(results, list(train_tournaments.index))
test_player_ans_correct, test_tour_quest_quantity = get_tour_statistics(results, list(test_tournaments.index))

# %% [markdown]
# Заметим, что в данных есть игроки, которые играли в 2019-ом, но не играли в 2020-ом. Подумаем, что делать с такими "кадрами" дальше

# %%
set(train_player_ans_correct.keys()) == set(test_player_ans_correct.keys())
# Out:
# False

# %%
print(f'Sum of questions in 2019 is {sum(train_tour_quest_quantity.values())}')
print(f'Sum of questions in 2020 is {sum(test_tour_quest_quantity.values())}')
print(f'Num of players in 2019 is {len(train_player_ans_correct)}')
print(f'Num of players in 2020 is {len(test_player_ans_correct)}')
# Out:
# Sum of questions in 2019 is 33375
# Sum of questions in 2020 is 7753
# Num of players in 2019 is 59271
# Num of players in 2020 is 28301

# %%
player_idx = {player:idx for idx, player in enumerate(train_player_ans_correct.keys())}

# %% [markdown]
# Обучим логистическую регрессию, где её первыми весами будут выступать силы каждого игрока из тренировочной выборка + обучим сложность каждого вопроса из тренировочной выборки. <br>
# Каждое наблюдение будет состоять из игрока и вопроса, на который его команда (не)ответила. Будет считать, что игрок ответил на вопрос, если на него ответила команда в целом, так как проверить кто именно ответил на вопрос не представляется возможным. <br>
# Метками будут выступать булевы ответы на вопрос: 1 или 0, где 1- команда ответила на данный вопрос и 0 в противном случае <br>
# Заполняем разрежженную матрицу Х и y

# %%
def get_player_answers(results, tour_quest_sizes):
    col_step = 0
    player_answer = dd(list)
    num_answers = 0
    the_biggest = -1
    for tour_idx, quest_size in tour_quest_sizes.items():
        for team in results[tour_idx]:
            for quest_idx, answer in enumerate(team['mask']):
                for member in team['teamMembers']:
                    player_id = member['player']['id']
                    player_answer[player_id].append((len(player_idx) + col_step + quest_idx, answer))
                    num_answers += 1
                    if len(player_idx) + col_step + quest_idx > the_biggest:
                        the_biggest = len(player_idx) + col_step + quest_idx
        col_step += quest_size
    return num_answers, player_answer


def fill_X_y(player_answers):
    row_id = 0
    rows = []
    cols = []
    data = []
    y = []
    for idx, answers in player_answers.items():
        for question_id, label in answers:
            rows.extend([row_id, row_id])
            cols.extend([question_id, player_idx[idx]])
            data.extend([1, 1])
            y.append(label)
            row_id += 1
    
    y = np.array(y)
    rows = np.array(rows)
    cols = np.array(cols)
    data = np.array(data)
    X = coo_matrix((data, (rows, cols)),
                   shape=(num_answers, len(player_idx) + sum(train_tour_quest_quantity.values())),
                   dtype=np.int8)
    return X, y

# %%
# %%time

num_answers, player_answers = get_player_answers(results, train_tour_quest_quantity)
X, y = fill_X_y(player_answers)
print(f'X dim = {X.shape}', f'Y dim = {y.shape}')
del player_answers
# Out:
# X dim = (21008480, 92646) Y dim = (21008480,)
# Wall time: 36 s

# %%
class CustomLogReg(LogisticRegression):
    
    def fit(self, X, y):
        super().fit(X, y)
        self.weights = self.coef_[0]
    
    def fine_tune_params(self, X, y, lr, max_iter=50):
        X_T = X.T
        ds_size = X.shape[0]
        losses = []
        prev_loss = 10
        for iteration in tqdm(range(max_iter)):
            preds = self.predict_probas(X)
            loss = self.log_loss(y, preds)
            grad = X_T @ (preds - y) / ds_size
            self.weights -= lr * grad
            losses.append(loss)
            
            if iteration % 10 == 0:
                if np.mean(losses) < prev_loss:    
                    prev_loss = np.mean(losses)
                    lr /= 10
                    print(f'LR={lr}')
                    print(f'AVGLogLoss={np.mean(losses)}')
                    losses = []
                else:
                    print("EarlyStopping")
                    break
    
    def predict_probas(self, X):
        logits = X @ self.weights
        return 1 / (1 + np.exp(-logits))
        
    @staticmethod
    def log_loss(y, p):
        return -np.mean(y * np.log(p) + (1 - y) * np.log(1 - p))

# %%
# %%time

clf = CustomLogReg(random_state=41, solver='saga', fit_intercept=True, n_jobs=-1, multi_class='ovr', tol=0.1)
clf.fit(X, y)
# Out:
# Wall time: 2min 17s

# %%
player_ratings = clf.coef_[0, :len(player_idx)]

# %%
# %%time

data = []

for player_id, num_corr_answers in train_player_ans_correct.items():
    player_info = players.loc[player_id]
    meta_info = {
        'rating': player_ratings[player_idx[player_id]],
        'true_answers': num_corr_answers,
        'name': player_info['name'],
        'surname': player_info['surname'],
        'patronymic': player_info['patronymic'],
    }
    data.append(meta_info)

pred_rating = pd.DataFrame(data)
# Out:
# Wall time: 3.76 s

# %% [markdown]
# Рейтинги топ игроков по мнению логистической регрессии. Для оценки силы каждого игрока брались соответствующие веса модели.

# %%
pred_rating.sort_values(by=['rating'], ascending=False).head(30)
# Out:
#          rating  true_answers        name        surname      patronymic
# 8222   4.100847          1980      Максим          Руссо      Михайлович
# 5957   4.015964          2409  Александра         Брутер    Владимировна
# 1209   3.984316          3242        Иван        Семушин      Николаевич
# 155    3.794658          4000       Артём       Сорожкин       Сергеевич
# 8244   3.777393          3202      Сергей        Спешков      Леонидович
# 1208   3.773779          2843      Михаил      Савченков    Владимирович
# 1210   3.630585          1279   Станислав    Мереминский     Григорьевич
# 3      3.625982          1548      Сергей      Николенко        Игоревич
# 20010  3.555684          1172        Илья        Новиков       Сергеевич
# 5      3.551417           849       Ирина     Прокофьева       Сергеевна
# 17839  3.543902           919     Дмитрий        Карякин   Александрович
# 1296   3.536757          1729     Наталья       Горелова      Евгеньевна
# 9661   3.531662          1093       Антон       Саксонов    Владимирович
# 1      3.523220          3007   Александр          Либер      Витальевич
# 17840  3.511557           791       Мария     Кленницкая    Владимировна
# 21614  3.510447           325      Михаил          Царёв       Сергеевич
# 44664  3.506164            35       Павел        Щербина  Константинович
# 17822  3.493905           820   Александр        Мосягин    Владимирович
# 6      3.479173          1215        Юлия  Архангельская       Сергеевна
# 17841  3.461314           930       Игорь          Мокин      Викторович
# 5931   3.440033          2224   Александр         Марков      Валерьевич
# 1298   3.439860          2437     Николай      Коврижных   Александрович
# 5930   3.435663          2334      Михаил      Новосёлов       Андреевич
# 1207   3.434657          3573     Алексей          Гилёв    Владимирович
# 5934   3.426915           524     Сусанна         Бровер        Марковна
# 1299   3.423770          2211    Кристина      Кораблина        Олеговна
# 0      3.402809          2443        Юрий        Выменец       Яковлевич
# 2      3.394430          1132      Михаил   Левандовский           Ильич
# 20537  3.393578           437       Мария          Юнгер      Алексеевна
# 22601  3.393304           345     Евгений          Дёмин      Васильевич

# %%
def predict_team_score(members, player_ratings):
    member_scores = []
    for member in members:
        member_id = member['player']['id']
        
        if player_idx.get(member_id):
            score = player_ratings[player_idx[member_id]]
        else:
            score = 0
        member_scores.append(score)
    return sum(member_scores) / len(members)

# %%
def calculate_local_corr(pred: List[Tuple[str, int]], act: Dict[str, int]):
    act_arr = []
    pred_arr = []
    
    for name, pred_rating in pred:
        act_arr.append(act[name])
        pred_arr.append(pred_rating)
    
    spearman_corr = stats.spearmanr(act_arr, pred_arr).correlation
    kendalltau, _ = stats.kendalltau(act_arr, pred_arr)
    
    return spearman_corr, kendalltau

# %%
def calculate_average_correlations(results, player_ratings, indexes, print_axillary_info=True):
    spearman_corrs = []
    kendalltaus = []
    
    for tour_idx in indexes:
        true_team_ratings = {}
        pred_team_scores = []
        tour_name = tournaments.loc[tour_idx, 'name']
        for team in results[tour_idx]:
            true_rating = team['position']
            pred_score = predict_team_score(team['teamMembers'], player_ratings)
            true_team_ratings[team['team']['name']] = true_rating
            pred_team_scores.append((team['team']['name'], pred_score))
        
        sorted_scores = sorted(pred_team_scores, key=lambda x: x[1], reverse=True)
        pred_team_rating = [(name, idx + 1) for idx, (name, score) in enumerate(sorted_scores)]
        
        spearman_corr, kendalltau = calculate_local_corr(pred_team_rating, true_team_ratings)
        
        if pd.isnull(spearman_corr) or pd.isnull(kendalltau):
            continue
            
        spearman_corrs.append(spearman_corr)
        kendalltaus.append(kendalltau)
            
        if print_axillary_info:
            print(f'Tournament-{tour_name}',
                  f'Spearman corr={spearman_corr}',
                  f'Kendall corr={kendalltau}\n', sep='\n')
    
    avg_spearman_corr = sum(spearman_corrs) / len(spearman_corrs)
    avg_kendalltau = sum(kendalltaus) / len(kendalltaus)
    print(f"Avg Spearman correlation={avg_spearman_corr}",
          f'Avg Kendall correlation={avg_kendalltau}\n', sep='\n')

# %% [markdown]
# Чтобы оценить результаты турниров из тестовой выборки будем делать следующее: <br>
# Возьмём веса каждого игрока в команде и сложим их, после чего усредним по кол-ву человек. Это будет "сила" команды, после чего отранжируем команды по силе и посчитаем корреляции итоговых результатов с предсказанными.

# %%
calculate_average_correlations(results, player_ratings, list(test_tour_quest_quantity.keys()), True)
# Out:
# Tournament-Синхрон Биркиркары
# Spearman corr=0.7458270508091838
# Kendall corr=0.5801838669498017
#
# Tournament-Синхрон северных стран
# Spearman corr=0.8311346913783366
# Kendall corr=0.6550434180139159
#
# Tournament-Онлайн: Синхрон Урюбджирова
# Spearman corr=0.7846813665210466
# Kendall corr=0.6019902203220816
#
# Tournament-Школьный Синхрон-lite. Выпуск 3.6
# Spearman corr=0.860933622899259
# Kendall corr=0.6868603058996536
#
# Tournament-(а)Синхрон-lite. Лига старта. Эпизод XII
# Spearman corr=0.7820539700167828
# Kendall corr=0.6007176243364194
#
# Tournament-Школьный Синхрон-lite. Выпуск 3.7
# Spearman corr=0.8550240329059056
# Kendall corr=0.6893718779075506
#
# Tournament-Онлайн: (а)Синхрон-lite. Лига старта. Эпизод XIII
# Spearman corr=0.7499456479463605
# Kendall corr=0.5627736835884323
#
# Tournament-Школьный Синхрон-lite. Выпуск 3.8
# Spearman corr=0.6359578073820066
# Kendall corr=0.4672769009551165
#
# Tournament-Онлайн: (а)Синхрон-lite. Лига старта. Эпизод XIV
# Spearman corr=0.6317414957381032
# Kendall corr=0.4689099919897597
#
# Tournament-Синхрон Моносова
# Spearman corr=0.8698217548536894
# Kendall corr=0.6966556836920078
#
# Tournament-Синхрон-lite. Выпуск XXXI
# Spearman corr=0.808030146293241
# Kendall corr=0.6312770994341536
#
# Tournament-Синхрон-lite. Выпуск XXXII
# Spearman corr=0.760344312011928
# Kendall corr=0.5926572563348507
#
# Tournament-Синхрон-lite. Выпуск XXXIII
# Spearman corr=0.7794423795239729
# Kendall corr=0.6117785784204454
#
# Tournament-Онлайн: Синхрон-lite. Выпуск XXXIV
# Spearman corr=0.6993906302502466
# Kendall corr=0.5280093408728873
#
# Tournament-Открытый Чемпионат Кипра
# Spearman corr=0.8465934232139837
# Kendall corr=0.7172314024308494
#
# Tournament-Балтийский Берег. 3 игра
# Spearman corr=0.8527953848948484
# Kendall corr=0.682955165540261
#
# Tournament-Балтийский Берег. 4 игра
# Spearman corr=0.8475529413139048
# Kendall corr=0.6795700741453546
#
# Tournament-Документ Microsoft Word (2).docx
# Spearman corr=0.7727998663719053
# Kendall corr=0.607358654459943
#
# Tournament-Триптих. Зима
# Spearman corr=0.848563454309183
# Kendall corr=0.6841203708738584
#
# Tournament-Пятая октава: Тропик Козерога
# Spearman corr=0.8659713148833305
# Kendall corr=0.6968181879901066
#
# Tournament-Седьмая октава
# Spearman corr=0.8324044378553355
# Kendall corr=0.6587567609009883
#
# Tournament-Шестая октава
# Spearman corr=0.8457986358824571
# Kendall corr=0.6664334689142826
#
# Tournament-Чизкейк
# Spearman corr=0.6978821426345161
# Kendall corr=0.5274171014794025
#
# Tournament-Лига Сибири. IV тур.
# Spearman corr=0.8626169901195528
# Kendall corr=0.6899917408266939
#
# Tournament-Лига Сибири. V тур.
# Spearman corr=0.8372909492723086
# Kendall corr=0.6555629314254201
#
# Tournament-Гусарская лига. III сезон. III этап
# Spearman corr=0.5460900412938989
# Kendall corr=0.38382917271058187
#
# Tournament-ОВСЧ. 6 этап
# Spearman corr=0.8668843204431638
# Kendall corr=0.6980858597717802
#
# Tournament-Серия Premier. Громокипящий кубок
# Spearman corr=0.8363866919370622
# Kendall corr=0.6675341773900457
#
# Tournament-Серия Гран-при. 5 этап. Гран-при Азии
# Spearman corr=0.8965334426820235
# Kendall corr=0.7372535796493394
#
# Tournament-Серия Гран-при. 6 этап. Гран-при Восточной Европы
# Spearman corr=0.8824911688183436
# Kendall corr=0.7184834006237636
#
# Tournament-Лига вузов. V тур
# Spearman corr=0.8520178618050414
# Kendall corr=0.672063638688199
#
# Tournament-Славянка
# Spearman corr=0.7883782593275596
# Kendall corr=0.6166773915841292
#
# Tournament-Кубок малой родины
# Spearman corr=0.9042273419162815
# Kendall corr=0.766891090184763
#
# Tournament-Фрегат "Паллада": синхрон "Борского корабела"
# Spearman corr=0.8222401948073804
# Kendall corr=0.6498056521805108
#
# Tournament-Lida Major
# Spearman corr=0.8862166140622976
# Kendall corr=0.7500346732623102
#
# Tournament-Школьная лига. IV тур.
# Spearman corr=0.8692186095833033
# Kendall corr=0.7154833844225413
#
# Tournament-Школьная лига. V тур.
# Spearman corr=0.8602352247194365
# Kendall corr=0.6979362998438576
#
# Tournament-Школьная лига. VI тур.
# Spearman corr=0.8374923440339508
# Kendall corr=0.685770209814718
#
# Tournament-Олимпийский Кубок Беларуси
# Spearman corr=0.8446349550751915
# Kendall corr=0.6765947737049689
#
# Tournament-Синхрон с человеческим лицом VI
# Spearman corr=0.7893787595982834
# Kendall corr=0.6120925242668906
#
# Tournament-Январское диминуэндо
# Spearman corr=0.8450913782447985
# Kendall corr=0.7191012094028307
#
# Tournament-Части Вселенной
# Spearman corr=0.912714537953302
# Kendall corr=0.7747350115843986
#
# Tournament-Славянка без раздаток. 1 этап
# Spearman corr=0.7461322610007218
# Kendall corr=0.5721733565291992
#
# Tournament-Вышкафест
# Spearman corr=0.9378194607998109
# Kendall corr=0.8001722024176735
#
# Tournament-Гран-при Славянки. 1 этап
# Spearman corr=0.8630850994505027
# Kendall corr=0.6913965994406321
#
# Tournament-Славянка без раздаток. 2 этап
# Spearman corr=0.8417050146603817
# Kendall corr=0.6682305304241202
#
# Tournament-Гран-при Славянки. 2 этап
# Spearman corr=0.7938363746057493
# Kendall corr=0.6187636103390942
#
# Tournament-Кубок Бесконечности. V этап
# Spearman corr=0.8803267555757668
# Kendall corr=0.7179449361892956
#
# Tournament-Кубок Бесконечности. VI этап
# Spearman corr=0.8637942629348806
# Kendall corr=0.6965644050345678
#
# Tournament-Lida Major. День 1
# Spearman corr=0.14285714285714288
# Kendall corr=0.3333333333333333
#
# Tournament-Lida Major. День 2
# Spearman corr=0.5487115617999135
# Kendall corr=0.39706514588228864
#
# Tournament-Чемпионат Ростовской области
# Spearman corr=0.9353944639318176
# Kendall corr=0.8252712671357592
#
# Tournament-Кубок Белой Крысы
# Spearman corr=0.8699151828881705
# Kendall corr=0.7020583911523518
#
# Tournament-Октариновый синхрон
# Spearman corr=0.8981394250809387
# Kendall corr=0.7310420121735105
#
# Tournament-Синхронный Кубок Хайфы
# Spearman corr=0.8811667740146363
# Kendall corr=0.7161572764831327
#
# Tournament-Кубок Хайфы
# Spearman corr=0.925245085247349
# Kendall corr=0.7953397696052682
#
# Tournament-Леденец
# Spearman corr=0.7729919270965262
# Kendall corr=0.6002623518819299
#
# Tournament-Мемориал Дмитрия Коноваленко
# Spearman corr=0.7777350759233429
# Kendall corr=0.6126438776991566
#
# Tournament-Гран-при Текстильной столицы
# Spearman corr=0.8920548563392086
# Kendall corr=0.731155694961699
#
# Tournament-Азовский бриз
# Spearman corr=0.8751534481698713
# Kendall corr=0.7019696366339289
#
# Tournament-Кубок Физтеха
# Spearman corr=0.8982458904901885
# Kendall corr=0.742556132598696
#
# Tournament-Холодная голова
# Spearman corr=0.8594138451274848
# Kendall corr=0.7021938909718035
#
# Tournament-Dichtenszeit-3
# Spearman corr=0.8629686250045732
# Kendall corr=0.6852703982164494
#
# Tournament-Dichtenszeit-4
# Spearman corr=0.729162635999661
# Kendall corr=0.5672514667948625
#
# Tournament-ФранкенШТО
# Spearman corr=0.7772242309808423
# Kendall corr=0.6153374295728267
#
# Tournament-Сова бьян
# Spearman corr=0.8861782174274297
# Kendall corr=0.7207474101287841
#
# Tournament-Краснодарский рождественский турнир
# Spearman corr=0.8695381519823598
# Kendall corr=0.7091625114297497
#
# Tournament-Лёгкий Смоленск-4
# Spearman corr=0.7425026386849867
# Kendall corr=0.567095932424071
#
# Tournament-Пегас и лирохвост
# Spearman corr=0.6961389881706531
# Kendall corr=0.5465838874135603
#
# Tournament-Открытый Кубок Зеленограда
# Spearman corr=0.8809332503379361
# Kendall corr=0.7344289458114531
#
# Tournament-Регадо-А
# Spearman corr=0.856912905031828
# Kendall corr=0.7030830691499014
#
# Tournament-Молодёжный кубок Европы. Этап 1
# Spearman corr=0.8706477958418184
# Kendall corr=0.6919674686331831
#
# Tournament-Зимняя радуга
# Spearman corr=0.8949847147978651
# Kendall corr=0.7109056705415037
#
# Tournament-33
# Spearman corr=0.6980303552221738
# Kendall corr=0.5892556509887895
#
# Tournament-Неясная поляна
# Spearman corr=0.5611425419454067
# Kendall corr=0.41576092031014994
#
# Tournament-Случайному гостю
# Spearman corr=0.6926839984341119
# Kendall corr=0.5242417683773418
#
# Tournament-Части Вселенной 60–99
# Spearman corr=0.8641786754854877
# Kendall corr=0.6890371092461671
#
# Tournament-Умами
# Spearman corr=0.8017305072732376
# Kendall corr=0.6342626691018469
#
# Tournament-Онлайн: Парный асинхронный турнир ChGK is...
# Spearman corr=0.6984077130460149
# Kendall corr=0.5200628078500481
#
# Tournament-Серия Premier. F – значит февраль
# Spearman corr=0.8579213932744397
# Kendall corr=0.6838984918046738
#
# Tournament-Серия Premier. Мартовские иды
# Spearman corr=0.8170109329261721
# Kendall corr=0.640801422803912
#
# Tournament-Кубок Полесья
# Spearman corr=0.8313738639798689
# Kendall corr=0.6972166887783963
#
# Tournament-Кубок Ростова-на-Дону, день 2
# Spearman corr=0.7204347351463172
# Kendall corr=0.5340812765818376
#
# Tournament-Кубок Ростова-на-Дону, день 3
# Spearman corr=0.731126155013931
# Kendall corr=0.5477225575051661
#
# Tournament-Кубок Арктики
# Spearman corr=0.9193176026908143
# Kendall corr=0.7698609043377811
#
# Tournament-Кубок Сигулды
# Spearman corr=0.8313395833721468
# Kendall corr=0.6590728750065218
#
# Tournament-Битва при Марафоне
# Spearman corr=0.8142233199589389
# Kendall corr=0.6641806418489572
#
# Tournament-П'ята октава: Тропік Козерога. Ліга Націй: Україна
# Spearman corr=0.8046260581709502
# Kendall corr=0.6384534025641567
#
# Tournament-Пятая актава: Тропік Казярога. Ліга нацый: Беларусь
# Spearman corr=1.0
# Kendall corr=1.0
#
# Tournament-Зимний Синхронный Умлаут
# Spearman corr=0.8443665329835602
# Kendall corr=0.6677992943018267
#
# Tournament-Триптих. Весна
# Spearman corr=0.8436353216593983
# Kendall corr=0.6750778982526798
#
# Tournament-Краснодарский рождественский синхрон
# Spearman corr=0.9065980038338805
# Kendall corr=0.7460426260837066
#
# Tournament-Кубок соседней галактики. Гамма
# Spearman corr=0.6915661063474073
# Kendall corr=0.5449492609130661
#
# Tournament-Українська ліга. Етап 3
# Spearman corr=0.820923400961347
# Kendall corr=0.656411637537469
#
# Tournament-Честный Эйб
# Spearman corr=0.7262026526819089
# Kendall corr=0.5466775768841208
#
# Tournament-Студенческие игры БГУ
# Spearman corr=0.7161130684721135
# Kendall corr=0.5579393303006128
#
# Tournament-Синхрон Студенческих игр БГУ
# Spearman corr=0.8592542111483796
# Kendall corr=0.7117352953655323
#
# Tournament-Синхрон Олимпийского Кубка Беларуси. День 1
# Spearman corr=0.7989700163568424
# Kendall corr=0.6204728205553424
#
# Tournament-Второй Карагандинский марафон
# Spearman corr=0.7999999999999999
# Kendall corr=0.6666666666666669
#
# Tournament-Cotton Cup
# Spearman corr=0.8489335410351319
# Kendall corr=0.6835990727814749
#
# Tournament-Чемпионат Минска. Лига А. Тур третий
# Spearman corr=0.8089694918355221
# Kendall corr=0.6237269674626442
#
# Tournament-Синхронный кубок Беларуси
# Spearman corr=0.8792872068919414
# Kendall corr=0.7006334093126282
#
# Tournament-Зеркало Кубка Сигулды
# Spearman corr=0.8421296632042884
# Kendall corr=0.6720205966468137
#
# Tournament-Кавалькада волхвов
# Spearman corr=0.6727272727272727
# Kendall corr=0.5272727272727272
#
# Tournament-Синхронный Кубок Зеленограда
# Spearman corr=0.8792290849777905
# Kendall corr=0.715051284797535
#
# Tournament-VERSUS: Немец vs. Шагал
# Spearman corr=0.7978515418394364
# Kendall corr=0.6269863261242916
#
# Tournament-Львов Зимой. Ледокол
# Spearman corr=0.8297019654733926
# Kendall corr=0.6533443856584806
#
# Tournament-Львов зимой. Последняя республика
# Spearman corr=0.8375154239342082
# Kendall corr=0.6714345789016278
#
# Tournament-ВДИ - За милых дам!
# Spearman corr=0.6592956855561904
# Kendall corr=0.4899344203471233
#
# Tournament-Чемпионат США
# Spearman corr=0.9038701016927327
# Kendall corr=0.7295487504686337
#
# Tournament-ВиРуС
# Spearman corr=0.8018649655244263
# Kendall corr=0.6276551542444444
#
# Tournament-U-Mind Games
# Spearman corr=0.9500004072362015
# Kendall corr=0.8227192524551448
#
# Tournament-С чаем пойдёт (green)
# Spearman corr=0.775186615034757
# Kendall corr=0.5970814340265321
#
# Tournament-Синхрон кубка Физтеха
# Spearman corr=0.8989303245246113
# Kendall corr=0.7286380578568448
#
# Tournament-Онлайн-турнир Первенства Сибири
# Spearman corr=0.7890019899891743
# Kendall corr=0.6193751378498076
#
# Tournament-Синхрон Первенства Сибири
# Spearman corr=0.854931300330718
# Kendall corr=0.6889342136413801
#
# Tournament-Кубок дедушек-моделей
# Spearman corr=0.8078589847546441
# Kendall corr=0.6524831224372214
#
# Tournament-Интеллектуальная олимпиада ПФО среди школьников. Региональный этап
# Spearman corr=0.7158039901238442
# Kendall corr=0.6939838926615821
#
# Tournament-Гран-при им. Г.В. Плеханова
# Spearman corr=0.8935845571747322
# Kendall corr=0.7197057413896379
#
# Tournament-Шоста октава. Ліга Націй: Україна
# Spearman corr=0.8164015364237815
# Kendall corr=0.6297851513387149
#
# Tournament-Первенство Сибири
# Spearman corr=0.7289901730780636
# Kendall corr=0.5724176110253085
#
# Tournament-Кубок ИРМ
# Spearman corr=0.844385076187752
# Kendall corr=0.6656499149054161
#
# Tournament-Игры доброй воли
# Spearman corr=0.45744908472737167
# Kendall corr=0.3005648566255677
#
# Tournament-Открытый кубок КубГУ
# Spearman corr=0.9433521256477764
# Kendall corr=0.799245459579261
#
# Tournament-Открытый кубок Главы города Иваново
# Spearman corr=0.9373158648301408
# Kendall corr=0.7958385707034465
#
# Tournament-Бужский гард 5
# Spearman corr=0.7946324166063354
# Kendall corr=0.6336951248641062
#
# Tournament-Гран-при Бауманки. 3 этап
# Spearman corr=0.5665708283627386
# Kendall corr=0.4029114820126901
#
# Tournament-50 на двоих
# Spearman corr=0.7142857142857143
# Kendall corr=0.6
#
# Tournament-Первенство Сибири. Пролог
# Spearman corr=0.6978163271664268
# Kendall corr=0.547240588603731
#
# Tournament-Зеркало Окского марафона. Хороший
# Spearman corr=0.8052228675086996
# Kendall corr=0.6413895903122376
#
# Tournament-Зеркало Окского марафона. Плохой
# Spearman corr=0.6398125059226669
# Kendall corr=0.49889803457144316
#
# Tournament-Зеркало Окского марафона. Злой
# Spearman corr=0.7359437453117736
# Kendall corr=0.5920263585748321
#
# Tournament-Чемпионат Минска. Лига Б. Тур четвёртый
# Spearman corr=0.8659613500433133
# Kendall corr=0.7363870905303704
#
# Tournament-ТОСИК Open Spring
# Spearman corr=0.9510290142755579
# Kendall corr=0.8419495894921355
#
# Tournament-Большой шлем Славянки
# Spearman corr=0.7109268939350041
# Kendall corr=0.5247293412875871
#
# Tournament-Открытый синхронный кубок Беларуси
# Spearman corr=0.7576662177068457
# Kendall corr=0.5952608282361667
#
# Tournament-Синхрон Открытого кубка КубГУ: день первый
# Spearman corr=0.7652847564438573
# Kendall corr=0.5762997719013032
#
# Tournament-Синхрон Открытого кубка КубГУ: день второй
# Spearman corr=0.6852903140868428
# Kendall corr=0.5569187790453816
#
# Tournament-СтудЧАО
# Spearman corr=0.6204426693876203
# Kendall corr=0.4770467650229332
#
# Tournament-Софийские игры
# Spearman corr=0.3051761677724593
# Kendall corr=0.2709508044980626
#
# Tournament-Синхрон Вышкафеста
# Spearman corr=0.8209151598630704
# Kendall corr=0.6379745487901987
#
# Tournament-Мартовский Марш
# Spearman corr=0.7479410371122022
# Kendall corr=0.567190208783394
#
# Tournament-Интеллектуальная олимпиада ПФО среди студентов. Региональный этап
# Spearman corr=0.419010749651167
# Kendall corr=0.3677026529843381
#
# Tournament-Зимний Варан
# Spearman corr=0.7106757230620853
# Kendall corr=0.5304270886732182
#
# Tournament-Из Минска с любовью. Этап 4
# Spearman corr=0.7044282883452097
# Kendall corr=0.5551325669602205
#
# Tournament-Весенняя синхронная ласточка
# Spearman corr=0.8673338380841319
# Kendall corr=0.6959191296168921
#
# Tournament-Сьома октава. Ліга Націй: Україна
# Spearman corr=0.8272536839407482
# Kendall corr=0.6596799961969605
#
# Tournament-Синхрон от каких-то ноунеймов
# Spearman corr=0.5286980234519141
# Kendall corr=0.39411636536078903
#
# Tournament-Онлайн: Лёгкий Смоленск-5
# Spearman corr=0.6407142115357694
# Kendall corr=0.48683539495993833
#
# Tournament-Школьный Чемпионат Минской области
# Spearman corr=0.4845755886969867
# Kendall corr=0.3692744729379982
#
# Tournament-Славянка без раздаток. Общий зачёт
# Spearman corr=0.7827000636072012
# Kendall corr=0.5954593246389678
#
# Tournament-Гран-при Славянки. Общий зачёт
# Spearman corr=0.8008148415374611
# Kendall corr=0.6240348521339981
#
# Tournament-Чемпионат Минска. Лига А. Тур четвёртый
# Spearman corr=0.6801408015538046
# Kendall corr=0.4959522736447163
#
# Tournament-Студенческий чемпионат Ярославской области
# Spearman corr=0.7331338776612144
# Kendall corr=0.6481039922301568
#
# Tournament-Чемпионат Владимирской области
# Spearman corr=0.9414475933014357
# Kendall corr=0.8122235400811268
#
# Tournament-Кубок соседней галактики. Дельта
# Spearman corr=0.6220505359580397
# Kendall corr=0.4484773675373503
#
# Tournament-Чемпионат Самары
# Spearman corr=0.7899913789007709
# Kendall corr=0.6124472018807623
#
# Tournament-Буслик
# Spearman corr=0.3768692478064706
# Kendall corr=0.2528558164964056
#
# Tournament-50 на двоих
# Spearman corr=0.5075577974696965
# Kendall corr=0.3897345836915162
#
# Tournament-Чемпионат Минска. Лига Б. Тур пятый
# Spearman corr=0.7427425046726642
# Kendall corr=0.5539247027265568
#
# Tournament-Покорение Сибири. День 1
# Spearman corr=0.4433907403721553
# Kendall corr=0.38221151764183153
#
# Tournament-Покорение Сибири. День 2
# Spearman corr=0.46464822776642956
# Kendall corr=0.3948453247273463
#
# Tournament-Из Минска с любовью. Этап 5
# Spearman corr=0.8215948169372324
# Kendall corr=0.6383094928491317
#
# Tournament-Онлайн: 18-00 Пегас и лирохвост
# Spearman corr=0.5195745535550244
# Kendall corr=0.3209833376209784
#
# Tournament-Онлайн: 08:00 Лига старта-13
# Spearman corr=1.0
# Kendall corr=1.0
#
# Tournament-Онлайн: 08:00 Год театра
# Spearman corr=0.9999999999999999
# Kendall corr=0.9999999999999999
#
# Tournament-Онлайн: 19-30 Лёгкий Смоленск-5
# Spearman corr=0.4550441482054972
# Kendall corr=0.3126526997403612
# Tournament-Онлайн: 19-30 Зелёный шум
# Spearman corr=0.7448351067695265
# Kendall corr=0.5828965086259651
#
# Tournament-Онлайн: 19-30 Зелёный шум
# Spearman corr=0.7089715869408764
# Kendall corr=0.5621995873961274
#
# Tournament-Онлайн: 16:00 Зелёный шум
# Spearman corr=0.7387687194103584
# Kendall corr=0.5855400437691199
#
# Avg Spearman correlation=0.7793139742233105
# Avg Kendall correlation=0.6257196634936709

# %% [markdown]
# Так как мы не знаем какой именно игрок ответил на тот или иной вопрос из команды, попробуем предсказать на сколько вероятно именно он ответил на заданный вопрос, введя тем самым латентные переменные для EM алгоритма. <br>
# На Е шаге будем оценивать вероятность того, что именно рассматриваемый игрок ответил на заданный вопрос, учитывая силу каждого игрока из команды и сложность вопроса. При этом утверждаем, что игрок с нулевой вероятностью ответил на заданный вопрос, если вся команда не смогла на него ответить.<br>
# На M шаге модель будет корректировать силу игроков и сложность вопросов, обучаясь на вероятностях, что именно рассматриваемый в наблюдении игрок ответил на заданный вопрос.

# %%
tour_id = int
num_questions = int


class EM:
    def __init__(self, model, lr=10):
        self.model = model
        self.lr = lr
    
    def step_E(self, curr_player_id, question_id, team_member_ids):
        question_complexity = self.model.weights[question_id]
        cummulative_q = 1
        
        for member_id in team_member_ids:
            if member_id == curr_player_id:
                continue
            member_skill = self.model.weights[member_id]
            q = 1 - self.sigma(member_skill + question_complexity)
            cummulative_q *= q
        
        curr_member_skill = self.model.weights[curr_player_id]
        p = self.sigma(curr_member_skill + question_complexity)
        
        return p / (1 - cummulative_q + EPS)
    
    def step_M(self, X, y):
        self.model.fine_tune_params(X, y, self.lr)
    
    def init_updated_params(self, X, results, tournaments: Dict[tour_id, num_questions]):
        col_step = 0
        self.updated_params = []
        
        for tour_idx, size in tournaments.items():
            for team in results[tour_idx]:
                for q_idx, answer in enumerate(team['mask']):
                    team_member_ids = set([player_idx[member['player']['id']] 
                                           for member in team['teamMembers']])
                    for member in team['teamMembers']:
                        question_pos = len(player_idx) + col_step + q_idx
                        player_pos = player_idx[member['player']['id']]
                        self.updated_params.append((player_pos, question_pos, team_member_ids, answer))            
            col_step += size
    
    def train_epoch(self, X):
        y = []
        for player_id, question_id, team_member_ids, answer in tqdm(self.updated_params):
            #step_E
            if answer:
                hidden_state = self.step_E(player_id, question_id, team_member_ids)
            else:
                hidden_state = 0
                
            y.append(hidden_state)
            
        print("Start step M")
        y = np.array(y).clip(0, 1)
        self.step_M(X, y)
        
        return self.model
    
    @staticmethod
    def sigma(x):
        return 1 / (1 + np.exp(-x))

# %%
em_alg = EM(clf)

print("Start initialize train params")
em_alg.init_updated_params(X, results, train_tour_quest_quantity)
print("Finish")
# Out:
# Start initialize train params
# Finish

# %% [markdown]
#     Сделаем 5 итерации, чтобы посмотреть растут ли метрики, модель обновляется градиентым спуском без батчей. В процессе обучения learning rate уменьшается

# %%
for epoch in range(5):
    print(f'{epoch=}')
    clf = em_alg.train_epoch(X)
    player_ratings = clf.weights[:len(player_idx)]
    calculate_average_correlations(results, player_ratings, list(test_tour_quest_quantity.keys()), False)
# Out:
# epoch=0
#   0%|          | 0/21008480 [00:00<?, ?it/s]
# Start step M
#   0%|          | 0/50 [00:00<?, ?it/s]
# LR=1.0
# AVGLogLoss=1.2587905800949633
# LR=0.1
# AVGLogLoss=1.2583191412539552
# LR=0.01
# AVGLogLoss=1.2581258183390935
# LR=0.001
# AVGLogLoss=1.2581064909551773
# LR=0.0001
# AVGLogLoss=1.2581045582658592
# Avg Spearman correlation=0.7793568683032638
# Avg Kendall correlation=0.6258040297177829
#
# epoch=1
#   0%|          | 0/21008480 [00:00<?, ?it/s]
# Start step M
#   0%|          | 0/50 [00:00<?, ?it/s]
# LR=1.0
# AVGLogLoss=1.258180237459249
# LR=0.1
# AVGLogLoss=1.2577092875888747
# LR=0.01
# AVGLogLoss=1.257516165330028
# LR=0.001
# AVGLogLoss=1.2574968580120625
# LR=0.0001
# AVGLogLoss=1.2574949273293416
# Avg Spearman correlation=0.7792818678468878
# Avg Kendall correlation=0.6256723823613991
#
# epoch=2
#   0%|          | 0/21008480 [00:00<?, ?it/s]
# Start step M
#   0%|          | 0/50 [00:00<?, ?it/s]
# LR=1.0
# AVGLogLoss=1.2575705948761131
# LR=0.1
# AVGLogLoss=1.2571001339573904
# LR=0.01
# AVGLogLoss=1.2569072123461686
# LR=0.001
# AVGLogLoss=1.2568879250932898
# LR=0.0001
# AVGLogLoss=1.256885996417083
# Avg Spearman correlation=0.7792657107278157
# Avg Kendall correlation=0.625677026534741
#
# epoch=3
#   0%|          | 0/21008480 [00:00<?, ?it/s]
# Start step M
#   0%|          | 0/50 [00:00<?, ?it/s]
# LR=1.0
# AVGLogLoss=1.2569616521141223
# LR=0.1
# AVGLogLoss=1.2564916801257433
# LR=0.01
# AVGLogLoss=1.2562989591528038
# LR=0.001
# AVGLogLoss=1.2562796919640569
# LR=0.0001
# AVGLogLoss=1.2562777652942636
# Avg Spearman correlation=0.7792516587035001
# Avg Kendall correlation=0.6256705001343864
#
# epoch=4
#   0%|          | 0/21008480 [00:00<?, ?it/s]
# Start step M
#   0%|          | 0/50 [00:00<?, ?it/s]
# LR=1.0
# AVGLogLoss=1.2563534088931556
# LR=0.1
# AVGLogLoss=1.2558839258114256
# LR=0.01
# AVGLogLoss=1.2556914054664463
# LR=0.001
# AVGLogLoss=1.255672158340775
# LR=0.0001
# AVGLogLoss=1.255670233677293
# Avg Spearman correlation=0.7792292658700453
# Avg Kendall correlation=0.6256299063720921

# %%
start_id = 0
tournament_complexity = []
for tournament_id, max_quest in train_tour_quest_quantity.items():
    tour_info = {}
    complexity = []
    for quest_id in range(max_quest):
        complexity.append(clf.weights[len(player_idx) + start_id + quest_id])
    tour_info['complexity'] = np.median(complexity)
    tour_info['id'] = tournament_id
    tour_info['name'] = tournaments.loc[tournament_id, 'name']
    tournament_complexity.append(tour_info)
    start_id += max_quest

tournament_ratings = pd.DataFrame(tournament_complexity)

# %% [markdown]
# Топ турниров по вопросам получился в обратную сторону, интересно...

# %%
tournament_ratings.sort_values(by=['complexity'], ascending=True).head(30)
# Out:
#      complexity    id                                     name
# 665   -4.451443  6149  Чемпионат Санкт-Петербурга. Первая лига
# 43    -2.171684  5159             Первенство правого полушария
# 543   -2.139705  5928                              Угрюмый Ёрш
# 369   -1.861565  5684               Синхрон высшей лиги Москвы
# 641   -1.818074  6101                       Воображаемый музей
# 225   -1.795673  5515  Чемпионат Минска. Лига А. Тур четвёртый
# 13    -1.729834  5025                            Кубок городов
# 284   -1.711487  5587                         Записки охотника
# 390   -1.681907  5717                   Чемпионат Таджикистана
# 596   -1.665406  5996                 Тихий Донец: омут первый
# 26    -1.644069  5083                        Ускользающая сова
# 555   -1.638236  5943          Чемпионат Мира. Этап 2 Группа С
# 49    -1.631786  5186         VERSUS: Коробейников vs. Матвеев
# 138   -1.615649  5421                     Львов зимой. Адвокат
# 44    -1.573258  5161                                Антибинго
# 554   -1.568359  5942         Чемпионат Мира. Этап 2. Группа В
# 451   -1.538837  5795                             Кубок Москвы
# 130   -1.532601  5412            Серия Premier. Седьмая печать
# 67    -1.528314  5303             Мемориал Дмитрия Коноваленко
# 552   -1.506978  5940         Чемпионат Мира. Этап 1. Группа С
# 553   -1.499784  5941         Чемпионат Мира. Этап 2. Группа А
# 640   -1.474993  6098     Чемпионат Минска. Лига А. Тур второй
# 406   -1.456851  5741                   All Cats Are Beautiful
# 377   -1.453880  5693                         Знание – Сила VI
# 179   -1.423250  5465                         Чемпионат России
# 533   -1.343710  5910                    Синхрон Майка Иванова
# 265   -1.340630  5563                                     Линч
# 337   -1.271125  5647                              Крутое пике
# 545   -1.267041  5930   Зеркало мемориала памяти Михаила Басса
# 28    -1.251723  5098       Ра-II: синхрон "Борского корабела"

# %%
# %%time
player_ratings = clf.weights[:len(player_idx)]
data = []

for player_id, num_corr_answers in train_player_ans_correct.items():
    player_info = players.loc[player_id]
    meta_info = {
        'rating': player_ratings[player_idx[player_id]],
        'true_answers': num_corr_answers,
        'name': player_info['name'],
        'surname': player_info['surname'],
        'patronymic': player_info['patronymic'],
    }
    data.append(meta_info)

pred_rating = pd.DataFrame(data)
# Out:
# Wall time: 3.64 s

# %%
pred_rating.sort_values(by=['rating'], ascending=False).head(30)
# Out:
#          rating  true_answers        name        surname      patronymic
# 8222   4.097260          1980      Максим          Руссо      Михайлович
# 5957   4.006010          2409  Александра         Брутер    Владимировна
# 1209   3.975121          3242        Иван        Семушин      Николаевич
# 155    3.776710          4000       Артём       Сорожкин       Сергеевич
# 1208   3.766705          2843      Михаил      Савченков    Владимирович
# 8244   3.766015          3202      Сергей        Спешков      Леонидович
# 1210   3.626611          1279   Станислав    Мереминский     Григорьевич
# 3      3.622141          1548      Сергей      Николенко        Игоревич
# 20010  3.548989          1172        Илья        Новиков       Сергеевич
# 5      3.548975           849       Ирина     Прокофьева       Сергеевна
# 17839  3.539430           919     Дмитрий        Карякин   Александрович
# 1296   3.534376          1729     Наталья       Горелова      Евгеньевна
# 9661   3.529356          1093       Антон       Саксонов    Владимирович
# 1      3.516139          3007   Александр          Либер      Витальевич
# 21614  3.509147           325      Михаил          Царёв       Сергеевич
# 17840  3.507616           791       Мария     Кленницкая    Владимировна
# 44664  3.506012            35       Павел        Щербина  Константинович
# 17822  3.490579           820   Александр        Мосягин    Владимирович
# 6      3.475646          1215        Юлия  Архангельская       Сергеевна
# 17841  3.456682           930       Игорь          Мокин      Викторович
# 1298   3.435478          2437     Николай      Коврижных   Александрович
# 5931   3.430570          2224   Александр         Марков      Валерьевич
# 5930   3.426511          2334      Михаил      Новосёлов       Андреевич
# 1207   3.426384          3573     Алексей          Гилёв    Владимирович
# 5934   3.424497           524     Сусанна         Бровер        Марковна
# 1299   3.419215          2211    Кристина      Кораблина        Олеговна
# 0      3.398148          2443        Юрий        Выменец       Яковлевич
# 22601  3.392165           345     Евгений          Дёмин      Васильевич
# 2      3.391635          1132      Михаил   Левандовский           Ильич
# 20537  3.390920           437       Мария          Юнгер      Алексеевна
